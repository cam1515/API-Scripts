# %%
# import requests
# import requests
# url = 'https://api.orats.io/datav2/hist/hvs?token=17ef4c40-e284-4d61-b150-e838d458fbb6&ticker=AAPL&tradeDate=2022-08-08&fields=orHv1d'
# payload={}
# headers={}
# response = requests.request("GET", url, headers=headers, data=payload)
# print(response.text)


import requests
url = 'https://api.orats.io/datav2/hist/summaries?token=17ef4c40-e284-4d61-b150-e838d458fbb6&ticker=SPX'
payload={}
headers={}
response = requests.request("GET", url, headers=headers, data=payload)
with open('K:\\Trading\\Risk\\JSON\\ORATS.json','w') as f:
    f.write(response.text)

# %%
df_data.head()
# Out:
#   ticker   tradeDate  stockPrice  annActDiv  annIdiv  borrow30  borrow2y  \
# 0    SPX  2007-01-03     1416.60          0        0  0.039590  0.033218
# 1    SPX  2007-01-04     1418.34          0        0  0.042639  0.033891
# 2    SPX  2007-01-05     1408.34          0        0  0.040772  0.035676
# 3    SPX  2007-01-08     1412.84          0        0  0.042583  0.034854
# 4    SPX  2007-01-09     1412.11          0        0  0.041737  0.033799
#
#    confidence  exErnIv10d  exErnIv20d  ...  fbfwd90_60  fbfwd180_90  \
# 0    0.980661    0.095535    0.096636  ...     1.08227      1.11477
# 1    0.974247    0.088322    0.090718  ...     1.11920      1.19373
# 2    0.972677    0.099593    0.098969  ...     1.08227      1.08113
# 3    0.961078    0.102036    0.101584  ...     1.12297      1.14631
# 4    0.986230    0.106508    0.105151  ...     1.10146      1.14026
#
#    fbfwd90_30  fbfexErn30_20  fbfexErn60_30  fbfexErn90_60  fbfexErn180_90  \
# ...

# %%
# import pandas as pd
# df = pd.read_json(response.text)
# df_data = pd.DataFrame(df.data.values.tolist())
# df_data.head(50)

# df = pd.read_json('K:\\Trading\\Risk\\JSON\\ORATS.json')
# df_data = pd.DataFrame(df.data.values.tolist())
# df_data.tail(50)
df_data.to_excel('K:\\Trading\\Risk\\JSON\\excel.xlsx')
